# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Instalações

# %% [markdown]
# A seguir serão instaladas algumas bibliotecas necessárias para a execução do projeto.
# Além dos framesworks comuns, serão também considerados outros como pandas.

# %%
# http://pytorch.org/
from os.path import exists
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.1-{platform}-linux_x86_64.whl torchvision

# %%
# importando o dataset para o ambiente do colab
# !wget -cq https://github.com/udacity/pytorch_challenge/raw/master/cat_to_name.json
# !wget -cq https://s3.amazonaws.com/content.udacity-data.com/courses/nd188/flower_data.zip
# !rm -r flower_data || true
# !unzip -qq flower_data.zip

# %% [markdown]
# # Importações

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import time
from torch import nn, optim
from torch.optim import lr_scheduler
from torchvision import datasets, transforms, models
from torch.utils.data.sampler import SubsetRandomSampler
from collections import OrderedDict

# %% [markdown]
# # Pré-processamento

# %% [markdown]
# O modulo transforms do torchvision nos permite realizar algumas transformações nas imagens como rotacao e corte de diferentes maneiras. Será definido transformações diferentes no conjunto de treino e teste. OBS: o conjuto de validação aqui foi retirado do conjunto de treino e a pasta 'valid' foi deixada para teste.

# %%
# transformações para treino e teste
train_transforms = transforms.Compose([transforms.RandomRotation(45),
                                       transforms.RandomResizedCrop(224),
                                       transforms.RandomHorizontalFlip(), # flip horizontal
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])
                                      ])
test_transforms =  transforms.Compose([transforms.Resize(260),
                                       transforms.CenterCrop(224),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])
                                      ])

# %%
# carregando conjunto de treino
train_set = datasets.ImageFolder('/content/flower_data/train', transform=train_transforms)
# carregando conjuto de teste
test_set  = datasets.ImageFolder('/content/flower_data/valid', transform=test_transforms)

# %%
def val_prepare(val_size):
    # preparando conjunto de validação
    data_points = len(train_set)
    indices = list(range(data_points))
    np.random.shuffle(indices)
    split = int(np.floor(val_size * data_points))
    train_idx, valid_idx = indices[split:], indices[:split]
    return SubsetRandomSampler(train_idx), SubsetRandomSampler(valid_idx)

# %% [markdown]
# Para a manipulação do arquivo 'cat_to_name.json' será utilizada bibliotaca pandas. O objetivo é ordenar as classes para acessa-las posteriormente pelos indices, esses indices serão coincidentes com os números de cada classe.

# %%
def trat_classes(train_loader):
    # carregado arquivo
    classes = pd.read_json('/content/cat_to_name.json', lines=True)
    # ordenado as classes em uma lista
    classes_ordenadas =['none'] # não existe pasta nomeada 0
    for i in range(1, 103):
        classes_ordenadas.append(classes[i].item())
        
    # aproveirando  e printando algumas imagens
    
    # escolhendo um lote do conjuto de treino
    images, labels = next(iter(train_loader))
    # visualizando
    fig = plt.figure(figsize=(14,4));
    for i in range(1, 5):
        ax = fig.add_subplot(1, 5/1, i+1, xticks=[], yticks=[]);
        ax.imshow(np.squeeze(images[i].numpy().transpose((1, 2, 0))))
        ax.set_title('({})'.format(classes_ordenadas[labels[i]]))        
    
    return classes_ordenadas

# %%
tSamp, vSamp = val_prepare(0.2)

# dataloaders
test_loader  = torch.utils.data.DataLoader(test_set,  batch_size=32, shuffle=True)
train_loader = torch.utils.data.DataLoader(train_set, sampler=tSamp, batch_size=32)
valid_loader = torch.utils.data.DataLoader(train_set, sampler=vSamp, batch_size=32)

# %%
# visulizando imagens e ordenando classes
classes = trat_classes(train_loader)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
classes[1]
# Out:
# 'pink primrose'

# %% [markdown]
# # Criando rede

# %%
# ecolhendo a arquitetura resnet18 como modelo para transferencia de aprendizado
model = models.vgg19(pretrained=True)

# %%
clf = nn.Sequential(OrderedDict([
                           ('fc1', nn.Linear(25088, 4096)),
                           ('relu', nn.ReLU()),
                           ('dropout', nn.Dropout(p=0.3)),
                           ('fc2', nn.Linear(4096, 102)),
                           ('output', nn.LogSoftmax(dim=1))
                           ]))

# %%
# congelando as camadas convolucionais
for weights in model.parameters():
    weights.requires_grad = False

# %%
model.classifier = clf # substituindo a camada totoalmente conectada
criterio = nn.NLLLoss() # função de custo ideal para o uso da funcao de activação softmax
optimizer = optim.Adam(model.classifier.parameters(), lr=0.001) 
sched = lr_scheduler.StepLR(optimizer, step_size=4, gamma=0.1)

# %%
# testando se o cuda está disponível
if torch.cuda.is_available():
  device = 'cuda'
else:
  device = 'cpu'
model.to(device)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): ReLU(inplace)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): ReLU(inplace)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): ReLU(inplace)
#     (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (33): ReLU(inplace)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): ReLU(inplace)
#     (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (fc1): Linear(in_features=25088, out_features=4096, bias=True)
#     (relu): ReLU()
#     (dropout): Dropout(p=0.3)
#     (fc2): Linear(in_features=4096, out_features=102, bias=True)
#     (output): LogSoftmax()
#   )
# )

# %% [markdown]
# # Fase de treinamento

# %%
def validar(valid_loss):
    model.eval() # setando para modo de validaçao
    for images, labels in valid_loader:
        images, labels = images.to(device), labels.to(device)
        output = model.forward(images)
        loss = criterio(output, labels)
        valid_loss += loss.item()*images.size(0)
            
    valid_loss = valid_loss/len(valid_loader.dataset)
    return valid_loss

# %%
def treinar(train_loss):
    sched.step()
    model.train() # setando modelo para treinamento
    for data, target in train_loader:
        data, target = data.to(device), target.to(device) # movendo tensors para GPU
        optimizer.zero_grad() 
        output = model.forward(data)

        loss = criterio(output, target)
        loss.backward()
        optimizer.step()
            
        train_loss += loss.item()*data.size(0)
    train_loss = train_loss/len(train_loader.dataset)
    return train_loss

# %%
val, train = [], [] 
def aprender(epochs):
    valid_loss_min = np.inf
    comeco = time.time() # tempo de treinamento
    remain_ep = epochs
    for ep in range(epochs):
        train_loss = 0.0 
        valid_loss = 0.0
        remain_ep -= 1
        
        train_loss = treinar(train_loss)
        valid_loss = validar(valid_loss)
            
        
        
        # salvando perdas para plotar posteriormente
        train.append(train_loss)
        val.append(valid_loss)
        
        
        tempo_treino = time.time() - comeco # tempo de treinamento
        if ep == 0:
          tempo_epoch = (tempo_treino // 60) # tempo de cada epoca
          
        print('tempo de treinamento {:.0f}m {:.0f}s    tempo esperado: {:.0f} minutos'.format(tempo_treino // 60, tempo_treino % 60, tempo_epoch*remain_ep))
        print('epoch: {} \t train_loss: {:.7f} \t valid_loss: {:.7f}'.format(ep+1, train_loss, valid_loss))
        
        if valid_loss <= valid_loss_min:
            print('salvando modelo...')
            torch.save(model.state_dict(), 'final_vgg_19_trained.pt')
            valid_loss_min = valid_loss

# %%
 aprender(30) # aprendendo...
# Out:
# tempo de treinamento 4m 11s    tempo esperado: 116 minutos
# epoch: 1 	 train_loss: 2.4165235 	 valid_loss: 0.3178173
# salvando modelo...
# tempo de treinamento 8m 23s    tempo esperado: 112 minutos
# epoch: 2 	 train_loss: 1.2176005 	 valid_loss: 0.2576066
# salvando modelo...
# tempo de treinamento 12m 35s    tempo esperado: 108 minutos
# epoch: 3 	 train_loss: 1.1111778 	 valid_loss: 0.2535297
# salvando modelo...
# tempo de treinamento 16m 47s    tempo esperado: 104 minutos
# epoch: 4 	 train_loss: 0.9766192 	 valid_loss: 0.2425280
# salvando modelo...
# tempo de treinamento 20m 59s    tempo esperado: 100 minutos
# epoch: 5 	 train_loss: 0.7718347 	 valid_loss: 0.1769943
# salvando modelo...
# tempo de treinamento 25m 11s    tempo esperado: 96 minutos
# epoch: 6 	 train_loss: 0.6749804 	 valid_loss: 0.1685429
# salvando modelo...
# tempo de treinamento 29m 23s    tempo esperado: 92 minutos
# epoch: 7 	 train_loss: 0.6292216 	 valid_loss: 0.1704900
# tempo de treinamento 33m 33s    tempo esperado: 88 minutos
# epoch: 8 	 train_loss: 0.6056543 	 valid_loss: 0.1798057
# tempo de treinamento 37m 43s    tempo esperado: 84 minutos
# epoch: 9 	 train_loss: 0.5601167 	 valid_loss: 0.1745371
# tempo de treinamento 41m 53s    tempo esperado: 80 minutos
# epoch: 10 	 train_loss: 0.5934689 	 valid_loss: 0.1568077
# salvando modelo...
# tempo de treinamento 46m 5s    tempo esperado: 76 minutos
# epoch: 11 	 train_loss: 0.5726668 	 valid_loss: 0.1534160
# salvando modelo...
# tempo de treinamento 50m 18s    tempo esperado: 72 minutos
# epoch: 12 	 train_loss: 0.5697862 	 valid_loss: 0.1472296
# salvando modelo...
# tempo de treinamento 54m 30s    tempo esperado: 68 minutos
# epoch: 13 	 train_loss: 0.5733107 	 valid_loss: 0.1481175
# tempo de treinamento 58m 40s    tempo esperado: 64 minutos
# epoch: 14 	 train_loss: 0.5236868 	 valid_loss: 0.1693903
# tempo de treinamento 62m 50s    tempo esperado: 60 minutos
# epoch: 15 	 train_loss: 0.5754442 	 valid_loss: 0.1631137
# tempo de treinamento 67m 0s    tempo esperado: 56 minutos
# epoch: 16 	 train_loss: 0.5313478 	 valid_loss: 0.1606001
# tempo de treinamento 71m 9s    tempo esperado: 52 minutos
# epoch: 17 	 train_loss: 0.5463702 	 valid_loss: 0.1638216
# tempo de treinamento 75m 18s    tempo esperado: 48 minutos
# epoch: 18 	 train_loss: 0.5669720 	 valid_loss: 0.1631654
# tempo de treinamento 79m 27s    tempo esperado: 44 minutos
# epoch: 19 	 train_loss: 0.5651035 	 valid_loss: 0.1617667
# tempo de treinamento 83m 37s    tempo esperado: 40 minutos
# epoch: 20 	 train_loss: 0.5467605 	 valid_loss: 0.1640004
# tempo de treinamento 87m 46s    tempo esperado: 36 minutos
# epoch: 21 	 train_loss: 0.5802584 	 valid_loss: 0.1634972
# tempo de treinamento 91m 55s    tempo esperado: 32 minutos
# epoch: 22 	 train_loss: 0.5473821 	 valid_loss: 0.1565984
# tempo de treinamento 96m 5s    tempo esperado: 28 minutos
# epoch: 23 	 train_loss: 0.5374832 	 valid_loss: 0.1624189
# tempo de treinamento 100m 15s    tempo esperado: 24 minutos
# epoch: 24 	 train_loss: 0.5551774 	 valid_loss: 0.1578470
# tempo de treinamento 104m 24s    tempo esperado: 20 minutos
# epoch: 25 	 train_loss: 0.5626425 	 valid_loss: 0.1580766
# tempo de treinamento 108m 33s    tempo esperado: 16 minutos
# epoch: 26 	 train_loss: 0.5476421 	 valid_loss: 0.1683520
# tempo de treinamento 112m 41s    tempo esperado: 12 minutos
# epoch: 27 	 train_loss: 0.5510812 	 valid_loss: 0.1605803
# tempo de treinamento 116m 49s    tempo esperado: 8 minutos
# epoch: 28 	 train_loss: 0.5719777 	 valid_loss: 0.1600918
# tempo de treinamento 120m 57s    tempo esperado: 4 minutos
# epoch: 29 	 train_loss: 0.5480035 	 valid_loss: 0.1521748
# tempo de treinamento 125m 5s    tempo esperado: 0 minutos
# epoch: 30 	 train_loss: 0.5608056 	 valid_loss: 0.1641005

# %% [markdown]
# # Inferência

# %%
# visulizar testes
def image_show(model):
    model.to('cpu')
    images, labels = next(iter(test_loader))
    out = model(images)
    pred = torch.max(out, 1)[1]
   
    fig = plt.figure(figsize=(25,4));
    for idx in np.arange(10):
        # desnormalizando imagens
        aux = images[idx].numpy() / 2 + 0.5
        ax = fig.add_subplot(2, 10/2, idx+1, xticks=[], yticks=[]);
        ax.imshow(np.squeeze(aux.transpose((1, 2, 0))));
        ax.set_title('{} = [{}]'.format(classes[pred[idx].item()], classes[int(labels[idx])]))

# %%
def train_val_plot(train, val):
    fig = plt.figure(figsize=(10,10))
    ax = fig.add_subplot(221)
    ax.plot(train)
    ax.set_title('train loss');
    ax = fig.add_subplot(222)
    ax.plot(val,'r')
    ax.set_title('validation loss',);
    ax = fig.add_subplot(223)
    ax.plot(train, 'b')
    ax.plot(val, 'r')
    ax.set_title('train and validation')

# %%
def accuracy(model):
    model.to(device)
    test_loss = 0.0
    # listas com 102 elementos 0 do tipo float
    correct_classes = list(np.zeros(102)) 
    all_classes = list(np.zeros(102))
    
    model.eval() 
    for data, target in test_loader:
        data, target = data.to(device), target.to(device) # movendo para GPU
        # propagação
        output = model(data)
        loss = criterio(output, target)
    
        test_loss += loss.item()*data.size(0)
    
        prediction = torch.max(output, 1)[1] # predição de classes
        correct = prediction == target       # comparação booleana com os rotulos
        for i in range(target.shape[0]):     # iterando sob todas as imagens no lote
          label = target.data[i]            
          
          correct_classes[label] += correct[i].item()
          all_classes[label] += 1
    
    
    test_loss = test_loss / len(test_loader.dataset)
    print('test_loss : {:.6f}'.format(test_loss))  
  
    # metrica accurácia : classes corretamente classificadas sobre todas as classes
    print('total accuracy : {:.2f}'.format(np.sum(correct_classes) / np.sum(all_classes)))

# %%
model.load_state_dict(torch.load('/content/final_vgg_19_trained.pt')) # carrengando melhor modelo

# %%
accuracy(model) #calculando accurácia
# Out:
# test_loss : 0.361149
# total accuracy : 0.90

# %%
train_val_plot(train, val)

# %%
image_show(model)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
